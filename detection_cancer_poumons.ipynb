# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import tensorflow as tf
from tensorflow.keras.layers import Conv2D,Dense,MaxPooling2D,Flatten,BatchNormalization,Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.applications import VGG16
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.resnet import preprocess_input
import matplotlib.pyplot as plt
import cv2 as cv
from sklearn.utils import shuffle
from sklearn.metrics import confusion_matrix,classification_report
from keras.utils import to_categorical

import os

# %%
path = '/content/drive/Shareddrives/MACHINE LEARNING/Data/'
train_path_str = path + 'train'
val_path_str = path + 'valid'
test_path_str = path + 'test'

# %%
test_classes = os.listdir(test_path_str)

# %% [markdown]
# Avant d'analyser les images, il est nécessaire de les transformer et modifier dans un même format afin de travailler avec des données cohérentes et de même type et ainsi permettre à la machine de s'entraîner correctement et efficacement.
#
# La fonction *ImageDataGenerator* de la bibliothèqie *keras* permet de génerer tout une liste de transformations à appliquer aux différentes images données.
#
# Les paramètres :
# * preprocessing_function : ...
# * rotation_range : ...
# * width_shift_range : ...
# * height_shift_range : ...
# * shear_range : ...
# * zoom_range : ...
# * horizontal_flip : ...
# * vertical_flip : ...
# * dtype : ...

# %%
input_shape = (224,224,3)
num_classes = 4

trainGenertor = ImageDataGenerator(
    preprocessing_function = preprocess_input,
    rotation_range = 10,
    width_shift_range = 0.3,
    height_shift_range = 0.3,
    shear_range = 0.2,
    zoom_range = 0.1,
    horizontal_flip = True,
    vertical_flip = True,
    dtype = 'float32'
)
valGenertor = ImageDataGenerator(
    preprocessing_function = preprocess_input,
    dtype = 'float32'
)

testGenertor = ImageDataGenerator(
    preprocessing_function = preprocess_input,
    dtype = 'float32'
)

# %% [markdown]
# On applique pour chaque lot d'images les transformations établies précédemment par les "Generators (??)" pour obtenir des données standardisées.

# %%
train_data = trainGenertor.flow_from_directory(
    train_path_str,
    target_size = (224,224),
    batch_size = 16,
    class_mode = 'categorical'
)

val_data = valGenertor.flow_from_directory(
    val_path_str,
    target_size = (224,224),
    batch_size = 16,
    class_mode = 'categorical'
)

test_data = testGenertor.flow_from_directory(
    test_path_str,
    target_size = (224,224),
    batch_size = 16,
    class_mode = 'categorical',
    shuffle = False
)
# Out:
# Found 613 images belonging to 4 classes.
# Found 72 images belonging to 4 classes.
# Found 315 images belonging to 4 classes.

# %%
VGG16_model = VGG16(
    include_top = False,
    weights="imagenet",
    input_shape = input_shape
)
for layer in VGG16_model.layers :
  layer.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step

# %%
from keras.src.metrics.confusion_metrics import activations
model = Sequential()
model.add(VGG16_model)
model.add(BatchNormalization())
model.add(MaxPooling2D((2,2)))
model.add(Flatten())
model.add(Dense(1024,activation = 'relu'))
model.add(Dropout(0.3))
model.add(Dense(512,activation = 'relu'))
model.add(Dropout(0.3))
model.add(Dense(256,activation = 'relu'))
model.add(Dense(128,activation = 'relu'))
model.add(Dense(num_classes,activation = 'softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  batch_normalization (Batch  (None, 7, 7, 512)         2048
#  Normalization)
#
#  max_pooling2d (MaxPooling2  (None, 3, 3, 512)         0
#  D)
#
#  flatten (Flatten)           (None, 4608)              0
#
#  dense (Dense)               (None, 1024)              4719616
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 256)               131328
#
#  dense_3 (Dense)             (None, 128)               32896
#
#  dense_4 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 20125892 (76.77 MB)
# Trainable params: 5410180 (20.64 MB)
# Non-trainable params: 14715712 (56.14 MB)
# _________________________________________________________________

# %%
model.compile(
    optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy']
)
callbacks = [
    tf.keras.callbacks.EarlyStopping(patience=5),
    tf.keras.callbacks.ModelCheckpoint('model.h5',save_best_only=True),
    tf.keras.callbacks.TensorBoard(log_dir='logs')
]

# %%
results = model.fit(train_data,validation_data=val_data,epochs=100,verbose = 1)
# Out:
# Epoch 1/100
# 39/39 [==============================] - 172s 4s/step - loss: 1.5953 - accuracy: 0.3866 - val_loss: 1.8185 - val_accuracy: 0.4306
# Epoch 2/100
# 39/39 [==============================] - 13s 325ms/step - loss: 1.1983 - accuracy: 0.4861 - val_loss: 1.3996 - val_accuracy: 0.5556
# Epoch 3/100
# 39/39 [==============================] - 12s 314ms/step - loss: 1.0741 - accuracy: 0.5155 - val_loss: 0.9050 - val_accuracy: 0.5417
# Epoch 4/100
# 39/39 [==============================] - 13s 333ms/step - loss: 0.9577 - accuracy: 0.5873 - val_loss: 0.9833 - val_accuracy: 0.4167
# Epoch 5/100
# 39/39 [==============================] - 13s 333ms/step - loss: 0.9271 - accuracy: 0.5612 - val_loss: 0.8368 - val_accuracy: 0.5972
# Epoch 6/100
# 39/39 [==============================] - 13s 330ms/step - loss: 0.8993 - accuracy: 0.5742 - val_loss: 1.1572 - val_accuracy: 0.4583
# Epoch 7/100
# 39/39 [==============================] - 14s 365ms/step - loss: 0.8505 - accuracy: 0.6134 - val_loss: 0.7480 - val_accuracy: 0.6667
# Epoch 8/100
# 39/39 [==============================] - 13s 325ms/step - loss: 0.8136 - accuracy: 0.6248 - val_loss: 0.8360 - val_accuracy: 0.6806
# Epoch 9/100
# 39/39 [==============================] - 14s 351ms/step - loss: 0.7784 - accuracy: 0.6558 - val_loss: 0.8357 - val_accuracy: 0.6250
# Epoch 10/100
# 39/39 [==============================] - 13s 333ms/step - loss: 0.7208 - accuracy: 0.6770 - val_loss: 0.8016 - val_accuracy: 0.6667
# Epoch 11/100
# 39/39 [==============================] - 12s 317ms/step - loss: 0.6880 - accuracy: 0.6966 - val_loss: 0.6620 - val_accuracy: 0.7222
# Epoch 12/100
# 39/39 [==============================] - 13s 324ms/step - loss: 0.6943 - accuracy: 0.7276 - val_loss: 0.6928 - val_accuracy: 0.7361
# Epoch 13/100
# 39/39 [==============================] - 13s 325ms/step - loss: 0.6747 - accuracy: 0.7096 - val_loss: 0.8183 - val_accuracy: 0.6250
# Epoch 14/100
# 39/39 [==============================] - 13s 325ms/step - loss: 0.6091 - accuracy: 0.7439 - val_loss: 0.6634 - val_accuracy: 0.7917
# Epoch 15/100
# 39/39 [==============================] - 13s 326ms/step - loss: 0.6185 - accuracy: 0.7439 - val_loss: 0.5616 - val_accuracy: 0.7917
# Epoch 16/100
# 39/39 [==============================] - 13s 328ms/step - loss: 0.5993 - accuracy: 0.7602 - val_loss: 0.6679 - val_accuracy: 0.7083
# Epoch 17/100
# 39/39 [==============================] - 13s 334ms/step - loss: 0.4924 - accuracy: 0.8140 - val_loss: 1.0377 - val_accuracy: 0.6111
# 39/39 [==============================] - 13s 331ms/step - loss: 0.2418 - accuracy: 0.9038 - val_loss: 1.0226 - val_accuracy: 0.7778
# Epoch 75/100
# 39/39 [==============================] - 13s 317ms/step - loss: 0.2573 - accuracy: 0.9005 - val_loss: 0.8247 - val_accuracy: 0.8194
# Epoch 76/100
# 39/39 [==============================] - 13s 325ms/step - loss: 0.1837 - accuracy: 0.9331 - val_loss: 0.9950 - val_accuracy: 0.8194
# Epoch 77/100
# 39/39 [==============================] - 13s 328ms/step - loss: 0.1994 - accuracy: 0.9250 - val_loss: 0.7955 - val_accuracy: 0.8056
# Epoch 78/100
# 39/39 [==============================] - 13s 325ms/step - loss: 0.2142 - accuracy: 0.9119 - val_loss: 0.7354 - val_accuracy: 0.8472
# Epoch 79/100
# 39/39 [==============================] - 13s 325ms/step - loss: 0.1983 - accuracy: 0.9266 - val_loss: 0.7330 - val_accuracy: 0.8472
# Epoch 80/100
# 39/39 [==============================] - 13s 326ms/step - loss: 0.2611 - accuracy: 0.9103 - val_loss: 0.6698 - val_accuracy: 0.8611
# Epoch 81/100
# 39/39 [==============================] - 13s 328ms/step - loss: 0.2052 - accuracy: 0.9233 - val_loss: 1.0895 - val_accuracy: 0.7917
# Epoch 82/100
# 39/39 [==============================] - 13s 325ms/step - loss: 0.2569 - accuracy: 0.9005 - val_loss: 0.8498 - val_accuracy: 0.8056
# Epoch 83/100
# 39/39 [==============================] - 13s 326ms/step - loss: 0.2615 - accuracy: 0.8891 - val_loss: 0.7484 - val_accuracy: 0.8333
# Epoch 84/100
# 39/39 [==============================] - 13s 322ms/step - loss: 0.1926 - accuracy: 0.9233 - val_loss: 0.7568 - val_accuracy: 0.8611
# Epoch 85/100
# 39/39 [==============================] - 13s 327ms/step - loss: 0.2038 - accuracy: 0.9282 - val_loss: 0.8668 - val_accuracy: 0.8194
# Epoch 86/100
# 39/39 [==============================] - 13s 337ms/step - loss: 0.2338 - accuracy: 0.9119 - val_loss: 0.6088 - val_accuracy: 0.8750
# Epoch 87/100
# 39/39 [==============================] - 13s 325ms/step - loss: 0.2319 - accuracy: 0.9119 - val_loss: 0.6986 - val_accuracy: 0.8611
# Epoch 88/100
# 39/39 [==============================] - 12s 320ms/step - loss: 0.1783 - accuracy: 0.9396 - val_loss: 1.0210 - val_accuracy: 0.7917
# Epoch 89/100
# 39/39 [==============================] - 13s 327ms/step - loss: 0.1868 - accuracy: 0.9364 - val_loss: 0.8169 - val_accuracy: 0.8472
# Epoch 90/100
# 39/39 [==============================] - 13s 326ms/step - loss: 0.2738 - accuracy: 0.8989 - val_loss: 0.6993 - val_accuracy: 0.8889
# Epoch 91/100
# 39/39 [==============================] - 12s 307ms/step - loss: 0.1588 - accuracy: 0.9347 - val_loss: 1.0154 - val_accuracy: 0.8333
# Epoch 92/100
# 39/39 [==============================] - 13s 326ms/step - loss: 0.1402 - accuracy: 0.9478 - val_loss: 1.1490 - val_accuracy: 0.8472
# Epoch 93/100
# 39/39 [==============================] - 13s 324ms/step - loss: 0.2388 - accuracy: 0.9233 - val_loss: 0.8192 - val_accuracy: 0.8611
# Epoch 94/100
# 39/39 [==============================] - 13s 327ms/step - loss: 0.1937 - accuracy: 0.9266 - val_loss: 0.8627 - val_accuracy: 0.8472
# Epoch 95/100
# 39/39 [==============================] - 13s 328ms/step - loss: 0.2534 - accuracy: 0.9201 - val_loss: 0.5501 - val_accuracy: 0.8611
# Epoch 96/100
# 39/39 [==============================] - 14s 373ms/step - loss: 0.1897 - accuracy: 0.9413 - val_loss: 0.5189 - val_accuracy: 0.8750
# Epoch 97/100
# 39/39 [==============================] - 13s 321ms/step - loss: 0.1747 - accuracy: 0.9380 - val_loss: 0.7159 - val_accuracy: 0.8750
# Epoch 98/100
# 39/39 [==============================] - 13s 326ms/step - loss: 0.2146 - accuracy: 0.9282 - val_loss: 0.6296 - val_accuracy: 0.8611
# Epoch 99/100
# 39/39 [==============================] - 13s 329ms/step - loss: 0.1890 - accuracy: 0.9282 - val_loss: 0.8518 - val_accuracy: 0.8472
# Epoch 100/100
# 39/39 [==============================] - 13s 324ms/step - loss: 0.2071 - accuracy: 0.9250 - val_loss: 0.7220 - val_accuracy: 0.8611

# %%
loss, acc = model.evaluate(test_data,verbose = 1)
# Out:
# 20/20 [==============================] - 90s 5s/step - loss: 0.3677 - accuracy: 0.8667

# %%
import seaborn as sns
predictions_prob = model.predict(test_data)
predictions = np.argmax(predictions_prob , axis = 1)
true_label = test_data.classes
report = classification_report(true_label,predictions)
print(report)
# Out:
# 20/20 [==============================] - 3s 151ms/step
#               precision    recall  f1-score   support
#
#            0       0.80      0.93      0.86       120
#            1       0.83      0.76      0.80        51
#            2       0.96      0.98      0.97        54
#            3       0.95      0.77      0.85        90
#
#     accuracy                           0.87       315
#    macro avg       0.88      0.86      0.87       315
# weighted avg       0.87      0.87      0.87       315

# %%
conf_mat = confusion_matrix(true_label,predictions)
sns.heatmap(conf_mat ,fmt='g',annot = True , cmap='Blues' , xticklabels=test_classes , yticklabels = test_classes,)
plt.xlabel('Predictions')
plt.ylabel('True label')
plt.title('Confusion Matrix')
plt.xticks(rotation = 45)
plt.show()

# %%
res = results.history
train_acc = res['accuracy']
val_accuracy = res['val_accuracy']
epochs = range(1, len(train_acc) + 1)

line1 = plt.plot(epochs, val_accuracy, label = 'Validation/Test Accuracy')
line2 = plt.plot(epochs, train_acc, label = 'Training Accuracy')

plt.setp(line1, linewidth = 1.8, marker = 'o', markersize = 6.5)
plt.setp(line2, linewidth = 1.8, marker = 's', markersize = 5)
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend()
plt.show()

# %%
res = results.history
train_loss = res['loss']
val_loss = res['val_loss']
epochs = range(1, len(train_loss) + 1)

line1 = plt.plot(epochs, val_loss, label = 'Validation/Test Loss')
line2 = plt.plot(epochs, train_loss, label = 'Training Loss')

plt.setp(line1, linewidth = 1.8, marker = 'o', markersize = 6.5)
plt.setp(line2, linewidth = 1.8, marker = 's', markersize = 5)
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend()
plt.show()
